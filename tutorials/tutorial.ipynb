# %% [markdown]
# # Tutorial
#
# If you launched this using the "template" launcher in the Janelia jupyterhub instance, there may be lots of extra whitespace in the cells below.
#
# (That should be fixed with the next JupyterHub update.)
#
# For now, you'll be better off copying the template yourself, and using that copy of the notebook:

# %%
# %%bash
# cp /misc/sc/jupyterhub/etc/jupyter/templates/ngsidekick-tutorial/tutorial.ipynb ~/ngsidekick-tutorial.ipynb

# %%
import os
import copy
import json
import numpy as np
import pandas as pd

import ngsidekick as ngsk

# %%
# Some cells below will write their outputs to this directory.
TUTORIAL_EXPORTS = 'ngsidekick-tutorial-exports'
os.makedirs(TUTORIAL_EXPORTS, exist_ok=True)

# %% [markdown]
# # Neuroglancer State

# %% [markdown]
# Neuroglancer links encode a JSON object that captures nearly all viewer state: layer visibility, camera orientation, etc.
#
# [1]: https://neuroglancer-demo.appspot.com/#!gs://flyem-male-cns/v0.9/male-cns-v0.9.json

# %%
template_state = ngsk.parse_nglink('https://neuroglancer-demo.appspot.com/#!gs://flyem-user-links/short/ngsidekick-tutorial-example-scene-1.json')

# %% [markdown]
# Most of the top-level keys control the global viewer settings: Coordinate space, camera orientation, zoom level, panel layout, etc.

# %%
template_state
# Out:
# {'title': 'Example Scene 1',
#  'dimensions': {'x': [8e-09, 'm'], 'y': [8e-09, 'm'], 'z': [8e-09, 'm']},
#  'position': [48311.5, 25295.765625, 28511.5],
#  'crossSectionScale': 88.13122564876332,
#  'projectionOrientation': [0, -0.002181659685447812, 0, 0.999997615814209],
#  'projectionScale': 99656.51830908704,
#  'layers': [{'type': 'image',
#    'source': {'url': 'precomputed://gs://flyem-male-cns/em/em-clahe-jpeg',
#     'subsources': {'default': True},
#     'enableDefaultSubsources': False},
#    'tab': 'rendering',
#    'name': 'em-clahe'},
#   {'type': 'segmentation',
#    'source': {'url': 'precomputed://gs://flyem-male-cns/v0.9/segmentation',
#     'subsources': {'default': True, 'properties': True, 'mesh': True},
#     'enableDefaultSubsources': False},
#    'tab': 'segments',
#    'segments': [],
#    'name': 'cns-seg'}],
#  'showSlices': False,
#  'selectedLayer': {'flex': 1.57,
#   'size': 415,
#   'visible': True,
#   'layer': 'cns-seg'},
#  'layout': '4panel-alt'}

# %% [markdown]
# Neuroglancer stores the layers as a list (to preserve their order), but for programmatic manipulation it's convenient to access them by their `name`.  Here's a convenience function for that:

# %%
state = copy.deepcopy(template_state)
seg_layer = ngsk.layer_state(state, 'cns-seg')

# %%
# Select two neurons.
seg_layer['segments'] = ["10009", "10157"]

# %% [markdown]
# A (non-shortened) neuroglancer link includes the complete JSON state directly in the URL.  (It might be pretty long!)
#
# To turn our state into a URL, just URL-encode the JSON text and give it an appropriate prefix.

# %%
import urllib

encoded_state = urllib.parse.quote(json.dumps(state))

print("https://neuroglancer-demo.appspot.com/#!" + encoded_state)
# Out:
# https://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%5D%2C%20%22showSlices%22%3A%20false%2C%20%22selectedLayer%22%3A%20%7B%22flex%22%3A%201.57%2C%20%22size%22%3A%20415%2C%20%22visible%22%3A%20true%2C%20%22layer%22%3A%20%22cns-seg%22%7D%2C%20%22layout%22%3A%20%224panel-alt%22%7D

# %% [markdown]
# There's also a convenience function in ngsk for that:

# %%
ngsk.encode_ngstate('https://neuroglancer-demo.appspot.com', state)
# Out:
# 'https://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%5D%2C%20%22showSlices%22%3A%20false%2C%20%22selectedLayer%22%3A%20%7B%22flex%22%3A%201.57%2C%20%22size%22%3A%20415%2C%20%22visible%22%3A%20true%2C%20%22layer%22%3A%20%22cns-seg%22%7D%2C%20%22layout%22%3A%20%224panel-alt%22%7D'

# %% [markdown]
# It can be cumbersome to share long links, and not all standard link shorteners can handle neuroglancer links with complete fidelity. Fortunately, neuroglancer can also unpack the JSON state from a JSON file (as shown above in the link we used to load the initial state).  However, that requires hosting the JSON file somewhere, either over `https` or in a Google Storage bucket (prefixed with `gs://`).
#
# Janelia FlyEM offers a [neuroglancer link shortener][shortng] that stores your link in a GCS bucket (with caveats).  In addition to the Web UI, it has a REST API as shown here.
#
# [shortng]: https://shortng-bmcp5imp6q-uc.a.run.app/shortener.html
#
# (If you prefer to use your own GCS bucket, see the convenience functions in [`ngsidekick.gcs`][gcs].)
#
# [gcs]: https://janelia-flyem.github.io/ngsidekick/docs/gcs.html

# %%
import requests

SHORTENER_URL = 'https://shortng-bmcp5imp6q-uc.a.run.app/shortng'

r = requests.post(f'{SHORTENER_URL}', json={
        'state': state,

        'domain': 'https://neuroglancer.janelia.org',

        # Optional: A default name is chosen if you don't provide one.
        'filename': 'my-state.json',

        # Optional: A password to prevent others from writing to the same filename.
        # Note: Does NOT prevent others from using your link!
        'password': 'my-password',
    })

print(r.json())
# Out:
# {'link': 'https://neuroglancer.janelia.org#!gs://flyem-user-links/short/my-state.json'}

# %% [markdown]
# # Download Example data
#
# MaleCNS neuron properties and soma locations.
#
# Obtained from the [MaleCNS download page.][1]
#
# [1]: https://male-cns.janelia.org/download

# %%
body_annotations_url = 'https://storage.googleapis.com/flyem-male-cns/v0.9/connectome-data/flat-connectome/body-annotations-male-cns-v0.9-minconf-0.5.feather'
df = pd.read_feather(body_annotations_url)

# The "type" column has the cell type, but later on we'll use "type" to mean something else,
# so rename "type" -> "cell_type"
df = df.rename(columns={'type': 'cell_type'})

# Make the index correspond to the body ID
df.index = df['bodyId'].rename('segment')

print(df.columns)
df.head()
# Out:
# Index(['bodyId', 'flywireType', 'group', 'hemibrainType', 'instance',
#        'itoleeHl', 'somaSide', 'statusLabel', 'superclass', 'supertype',
#        'cell_type', 'class', 'entryNerve', 'fruDsx', 'matchingNotes',
#        'rootSide', 'assignedOlHex1', 'assignedOlHex2', 'mancBodyid',
#        'mancGroup', 'mancType', 'somaNeuromere', 'subclass', 'trumanHl',
#        'dimorphism', 'synonyms', 'birthtime', 'mancSerial', 'mcnsSerial',
#        'exitNerve', 'serialMotif', 'receptorType', 'somaLocation',
#        'tosomaLocation', 'status'],
#       dtype='object')
#          bodyId                      flywireType    group hemibrainType  \
# segment
# 10001     10001                            DNp01  10001.0   Giant Fiber
# 10002     10002                           OCG01d  10002.0         OCG01
# 10003     10003                              VCH  10003.0           VCH
# 10005     10005                          AOTU019  10005.0       AOTU019
# 10006     10006  VS1,VS2,VS3,VS4,VS5,VS6,VS7,VS8  10006.0            VS
#
#             instance          itoleeHl somaSide            statusLabel  \
# segment
# 10001    DNp01(GF)_R  putative_primary        R         Roughly traced
# 10002       OCG01d_L              None        L         Roughly traced
# 10003          VCH_R  putative_primary        R  Prelim Roughly traced
# 10005      AOTU019_R  putative_primary        R         Roughly traced
# 10006           VS_L        no_lineage        L  Prelim Roughly traced
#
#                  superclass supertype  ...                      synonyms  \
# segment                                ...
# 10001     descending_neuron      None  ...  Kennedy and Broadie 2018: GF
# 10002     visual_projection      None  ...                          None
# 10003    visual_centrifugal      None  ...                          None
# 10005          cb_intrinsic      None  ...                          None
# 10006     visual_projection     10006  ...                          None
#
#         birthtime mancSerial mcnsSerial exitNerve serialMotif  receptorType  \
# segment
# 10001       early        NaN        NaN      None        None          None
# 10002        None        NaN        NaN      None        None          None
# 10003       early        NaN        NaN      None        None          None
# 10005       early        NaN        NaN      None        None          None
# 10006        None        NaN        NaN      None        None          None
#
#                   somaLocation  tosomaLocation  status
# segment
# 10001    [37124, 22258, 36274]            None  Traced
# 10002    [50214, 10279, 27497]            None  Traced
# 10003    [46716, 21029, 15714]            None  Traced
# 10005    [41190, 18491, 12885]            None  Traced
# 10006    [69604, 28368, 42459]            None  Traced
#
# [5 rows x 35 columns]

# %% [markdown]
# # Local data server

# %% [markdown]
# In the rest of this notebook, we'll create files to load in neuroglancer.
#
# To actually used them, we must host them via http somehow.  One option is to upload them to a Google Storage Bucket, or to host them on your own web server.
#
# Just for convenient development and debug, ngsidekick provides an http server that will let you browse files on your own machine.

# %%
server_port = 9091
server_proc, server_address, log_file = ngsk.serve_directory(TUTORIAL_EXPORTS, port=server_port, background=True, log_to_file=True)
TUTORIAL_DATA_ADDRESS = server_address
print(server_address)

# Note: Call server_proc.terminate() to stop the server.
# Out:
# http://10.8.4.100:9091

# %% [markdown]
# ### Tip: Janelia users have the option of using FileGlancer to host their data!
#
# https://fileglancer.int.janelia.org

# %%
# Only run this cell if you're using FileGlancer instead of the local server above!

# Data link, copied from the FileGlancer website.
TUTORIAL_DATA_ADDRESS = 'https://fileglancer.int.janelia.org/fc/files/MgV-YDzs9gEEwzTR/ngsidekick-tutorial-exports'

# %% [markdown]
# # Segment Properties

# %% [markdown]
# Neuroglancer can display a label (name) next to the segment IDs in the side panel.
#
# The names must come from a "segment properties" source.  Let's create our own.

# %%
# Just for illustration, we'll add a suffix to the type name to indicate if the cell has a soma or not.
new_df = df.query('cell_type.notnull()').copy()
df['mylabel'] = df['cell_type']
df.loc[df['somaLocation'].notnull(), 'mylabel'] += ' (has soma)'

# Write the new segment properties.
# We must place them in a file named 'info' in an otherwise empty directory.
info = ngsk.segment_properties_json(df[['mylabel']], 'mylabel', output_path=f'{TUTORIAL_EXPORTS}/mysegprops/info')

# %%
df[['mylabel']]
# Out:
#                        mylabel
# segment
# 10001         DNp01 (has soma)
# 10002        OCG01d (has soma)
# 10003           VCH (has soma)
# 10005       AOTU019 (has soma)
# 10006            VS (has soma)
# ...                        ...
# 1571382316                None
# 1571573938                None
# 1571585036                None
# 1571679990                None
# 1571825087                None
#
# [211743 rows x 1 columns]

# %% [markdown]
# You can view the new segment properties by manually adding a new "source" to the segmentation layer in your neuroglancer view.
#
# Here's how to do it programmatically.

# %%
new_state = copy.deepcopy(state)
seg_layer = ngsk.layer_state(new_state, 'cns-seg')

# Don't use the properties provided in the original data;
# we want to use our own.
if 'properties' in seg_layer['source']['subsources']:
    del seg_layer['source']['subsources']['properties']

# Convert 'source' to a list so we can add a second entry.
if not isinstance(seg_layer['source'], list):
    seg_layer['source'] = [seg_layer['source']]

# Add our new source, using the local server address.
seg_layer['source'].append(f'precomputed://{TUTORIAL_DATA_ADDRESS}/mysegprops')

# Note: If you're using a local data server and you don't refer to it via 'localhost',
# then you can't use https here.  We use bare http instead.
ngsk.encode_ngstate('http://neuroglancer-demo.appspot.com', new_state)
# Out:
# 'http://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%5B%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22precomputed%3A//http%3A//10.8.4.100%3A9091/mysegprops%22%5D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%5D%2C%20%22showSlices%22%3A%20false%2C%20%22selectedLayer%22%3A%20%7B%22flex%22%3A%201.57%2C%20%22size%22%3A%20415%2C%20%22visible%22%3A%20true%2C%20%22layer%22%3A%20%22cns-seg%22%7D%2C%20%22layout%22%3A%20%224panel-alt%22%7D'

# %% [markdown]
# ### Segment properties: Tags
#
# You can also add 'tags' to your segment properties.

# %%
new_df = df.copy()

# Tags can be created from boolean columns (true entries get the tag)
# or from string/categorical columns (in which case the tag name is prefixed with the column name)
df['has_soma'] = df['somaLocation'].notnull()

info = ngsk.segment_properties_json(
    df[['cell_type', 'superclass', 'has_soma']],
    label_col='cell_type',
    tag_cols=['superclass', 'has_soma'],
    output_path=f'{TUTORIAL_EXPORTS}/mysegprops/info'
)

# Now refresh your browser to see the new tags we exported.

# %% [markdown]
# # Point Annotations

# %% [markdown]
# Neuroglancer can also show various types of vector annotations: points, lines, boxes, ellipsoids.
#
# NGSidekick comes with a function for constructing such annotations from a DataFrame.
#
# We'll use the MaleCNS soma locations for this example.

# %%
# Extract the rows with a soma location
soma_df = df.dropna(subset='somaLocation').copy()
soma_df[[*'xyz']] = soma_df['somaLocation'].tolist()

print(soma_df.shape)
soma_df[['bodyId', 'cell_type', *'xyz']].head()
# Out:
# (141780, 40)
#          bodyId cell_type      x      y      z
# segment
# 10001     10001     DNp01  37124  22258  36274
# 10002     10002    OCG01d  50214  10279  27497
# 10003     10003       VCH  46716  21029  15714
# 10005     10005   AOTU019  41190  18491  12885
# 10006     10006        VS  69604  28368  42459

# %% [markdown]
# # Local Annotations
# To visualize just a few points, neuroglancer allows "local" annotations -- stored directly in the neuroglancer link (JSON state).

# %%
# Neuroglancer allows local annotation layers to contain a mix of annotation types (points, lines, boxes, etc.)
Tm9_soma_df = soma_df.query('cell_type == "Tm9"')
Tm9_soma_layer_json = ngsk.local_annotation_json(Tm9_soma_df, res_nm_xyz=(8, 8, 8))

# The output below can be pasted into the neuroglancer state.
print(json.dumps(Tm9_soma_layer_json))
# Out:
# {"name": "annotations", "type": "annotation", "source": {"url": "local://annotations", "transform": {"outputDimensions": {"x": [8e-09, "m"], "y": [8e-09, "m"], "z": [8e-09, "m"]}}}, "tool": "annotatePoint", "shader": "void main() {\n    //\n    // Point Marker API\n    //\n    setPointMarkerSize(8.0);\n    setPointMarkerColor(vec4(defaultColor(), 1.0));\n    setPointMarkerBorderWidth(1.0);\n    setPointMarkerBorderColor(defaultColor());\n}\n", "annotations": [{"type": "point", "id": "0x4afc61167bac5bb", "point": [75339, 18690, 24056]}, {"type": "point", "id": "0x32bf3849fa0e4ad8", "point": [82763, 46908, 29906]}, {"type": "point", "id": "0x3431ea1a6f49b5b2", "point": [81099, 40221, 23977]}, {"type": "point", "id": "0x66d15faa774fd487", "point": [76408, 21362, 22562]}, {"type": "point", "id": "0x2299594ae5968c6d", "point": [89208, 18548, 33472]}, {"type": "point", "id": "0x6fdb3c3577be4f35", "point": [78398, 33256, 20886]}, {"type": "point", "id": "0x324c9b594c9196ee", "point": [91380, 37474, 31212]}, {"type": "point", "id": "0x352b52dd538267f8", "point": [86988, 43496, 28908]}, {"type": "point", "id": "0x680f1ac18d739662", "point": [80244, 34418, 21788]}, {"type": "point", "id": "0x4ddf6df9698006d6", "point": [78968, 42843, 24010]}, {"type": "point", "id": "0x6b095ba1411518b0", "point": [78974, 15360, 26168]}, {"type": "point", "id": "0x26ef19d46122a5ae", "point": [90914, 30968, 36716]}, {"type": "point", "id": "0xb0b415cff7ad7b3", "point": [90916, 35030, 32320]}, {"type": "point", "id": "0x5e318bba4abd8f53", "point": [7974, 41520, 39594]}, {"type": "point", "id": "0xcf4d770adaf8aeb", "point": [90386, 24430, 32466]}, {"type": "point", "id": "0x159652c68d676715", "point": [91208, 35470, 34788]}, {"type": "point", "id": "0x64fec485b42bf0b3", "point": [78954, 47734, 26750]}, {"type": "point", "id": "0xe7cf7a4661f6293", "point": [85152, 23446, 29218]}, {"type": "point", "id": "0x5adde166580ba181", "point": [87090, 44942, 35856]}, {"type": "point", "id": "0x7d6aa3ef02578a94", "point": [83174, 14468, 33772]}, {"type": "point", "id": "0x66666991b4837b92", "point": [77070, 43774, 23050]}, {"type": "point", "id": "0x3a66758ee123b7a3", "point": [91330, 32194, 35138]}, {"type": "point", "id": "0x252a6f60afea33cf", "point": [85594, 45072, 29256]}, {"type": "point", "id": "0x65063f1930f17a1", "point": [79046, 45136, 25236]}, {"type": "point", "id": "0x3602e8317fbf8353", "point": [82027, 47174, 37329]}, {"type": "point", "id": "0x580873178c52f4eb", "point": [86302, 43390, 28776]}, {"type": "point", "id": "0x612f492351807d43", "point": [88126, 41877, 34916]}, {"type": "point", "id": "0x440af7442543eb4f", "point": [80954, 43384, 26570]}, {"type": "point", "id": "0x5d2d1cdbb6fbf8e7", "point": [78364, 49828, 31622]}, {"type": "point", "id": "0x5176af94c24d58c9", "point": [73570, 43211, 24113]}, {"type": "point", "id": "0x74195bece2516e2", "point": [89757, 40022, 30422]}, {"type": "point", "id": "0x5afa2a2e04b41378", "point": [92661, 26193, 34118]}, {"type": "point", "id": "0x5e2c54cf1d39b4bd", "point": [72232, 40344, 23604]}, {"type": "point", "id": "0x6f71a4f64715771d", "point": [89818, 33816, 38486]}, {"type": "point", "id": "0x61fa10682775286a", "point": [87746, 43871, 32218]}, {"type": "point", "id": "0x43a1ecc2ac791998", "point": [91288, 29947, 35593]}, {"type": "point", "id": "0x651a6c20cfd7b180", "point": [72839, 30167, 21461]}, {"type": "point", "id": "0x5fa5f27063a00a0", "point": [79266, 38436, 22762]}, {"type": "point", "id": "0x204223e4fc28a398", "point": [80642, 43502, 24748]}, {"type": "point", "id": "0x7fe35bbf1f7f18c8", "point": [12248, 34049, 27554]}, {"type": "point", "id": "0xc8e2a340c97c278", "point": [75076, 36658, 21490]}, {"type": "point", "id": "0x76f4d4bc606fce38", "point": [75194, 12738, 26808]}, {"type": "point", "id": "0x42725315160a0c16", "point": [15762, 16766, 28600]}, {"type": "point", "id": "0x7babc05cd42d9c87", "point": [82382, 28766, 24450]}, {"type": "point", "id": "0x5870682658898189", "point": [76836, 48445, ...

# %%
# Or add it programmatically to an existing neuroglancer state.
new_state = copy.deepcopy(state)
new_state['layers'].append(Tm9_soma_layer_json)
print(ngsk.encode_ngstate('http://neuroglancer-demo.appspot.com', new_state))
# Out:
# http://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%2C%20%7B%22name%22%3A%20%22annotations%22%2C%20%22type%22%3A%20%22annotation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22local%3A//annotations%22%2C%20%22transform%22%3A%20%7B%22outputDimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%7D%7D%2C%20%22tool%22%3A%20%22annotatePoint%22%2C%20%22shader%22%3A%20%22void%20main%28%29%20%7B%5Cn%20%20%20%20//%5Cn%20%20%20%20//%20Point%20Marker%20API%5Cn%20%20%20%20//%5Cn%20%20%20%20setPointMarkerSize%288.0%29%3B%5Cn%20%20%20%20setPointMarkerColor%28vec4%28defaultColor%28%29%2C%201.0%29%29%3B%5Cn%20%20%20%20setPointMarkerBorderWidth%281.0%29%3B%5Cn%20%20%20%20setPointMarkerBorderColor%28defaultColor%28%29%29%3B%5Cn%7D%5Cn%22%2C%20%22annotations%22%3A%20%5B%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x4afc61167bac5bb%22%2C%20%22point%22%3A%20%5B75339%2C%2018690%2C%2024056%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x32bf3849fa0e4ad8%22%2C%20%22point%22%3A%20%5B82763%2C%2046908%2C%2029906%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x3431ea1a6f49b5b2%22%2C%20%22point%22%3A%20%5B81099%2C%2040221%2C%2023977%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x66d15faa774fd487%22%2C%20%22point%22%3A%20%5B76408%2C%2021362%2C%2022562%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x2299594ae5968c6d%22%2C%20%22point%22%3A%20%5B89208%2C%2018548%2C%2033472%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x6fdb3c3577be4f35%22%2C%20%22point%22%3A%20%5B78398%2C%2033256%2C%2020886%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x324c9b594c9196ee%22%2C%20%22point%22%3A%20%5B91380%2C%2037474%2C%2031212%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x352b52dd538267f8%22%2C%20%22point%22%3A%20%5B86988%2C%2043496%2C%2028908%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x680f1ac18d739662%22%2C%20%22point%22%3A%20%5B80244%2C%2034418%2C%2021788%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x4ddf6df9698006d6%22%2C%20%22point%22%3A%20%5B78968%2C%2042843%2C%2024010%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x6b095ba1411518b0%22%2C%20%22point%22%3A%20%5B78974%2C%2015360%2C%2026168%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x26ef19d46122a5ae%22%2C%20%22point%22%3A%20%5B90914%2C%2030968%2C%2036716%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220xb0b415cff7ad7b3%22%2C%20%22point%22%3A%20%5B90916%2C%2035030%2C%2032320%5D%7D%2C%20%7B%22type%22%3A%20%22point%22%2C%20%22id%22%3A%20%220x5e318bba4abd8f53%22%2C%20%22point%22% ...

# %%
long_link = ngsk.encode_ngstate('https://neuroglancer-demo.appspot.com', state)

import requests
SHORTENER_URL = 'https://shortng-bmcp5imp6q-uc.a.run.app/shortng'
r = requests.post(f'{SHORTENER_URL}', json={'state': new_state})
r.content
# Out:
# b'{"link":"https://neuroglancer-demo.appspot.com/#!gs://flyem-user-links/short/2026-02-05.195813.423581.json"}\n'

# %% [markdown]
# # Precomputed Annotations

# %% [markdown]
# If you're dealing with lots of annotations (more than a few thousand), you'll need to export them in neuroglancer "precomputed" format.

# %%
# Fill empty values with a category that will correspond to code 0.
soma_df['itoleeHl'] = soma_df['itoleeHl'].fillna('').astype('category')
soma_df['trumanHl'] = soma_df['trumanHl'].fillna('').astype('category')

coord_space = {
    "names": ['x', 'y', 'z'],
    "units": ['nm', 'nm', 'nm'],
    "scales": [8, 8, 8]
}

ngsk.write_precomputed_annotations(
    soma_df,
    coord_space,
    'point',
    properties=['itoleeHl', 'trumanHl'],
    relationships=['bodyId'],
    output_dir=f'{TUTORIAL_EXPORTS}/soma_annotations',
)
# Out:
# [2026-02-05 14:58:15,371] INFO Encoding annotation IDs
# [2026-02-05 14:58:15,379] INFO Encoding annotation geometries and properties
# [2026-02-05 14:58:15,397] INFO Encoding relationships
# [2026-02-05 14:58:15,419] INFO Writing annotations to 'by_id' index
#   0%|          | 0/141780 [00:00<?, ?it/s]
# [2026-02-05 14:58:16,310] INFO Grouping annotations by relationship bodyId
# [2026-02-05 14:58:17,554] INFO Combining annotation and ID buffers for relationship 'bodyId'
# [2026-02-05 14:58:17,582] INFO Writing annotations to 'by_rel_bodyId' index
#   0%|          | 0/141780 [00:00<?, ?it/s]
# [2026-02-05 14:58:18,536] INFO Shuffling annotations before assigning spatial grid levels
# [2026-02-05 14:58:18,542] INFO Assigning spatial grid chunks
# [2026-02-05 14:58:18,763] INFO Done assigning spatial grid chunks
# [2026-02-05 14:58:18,764] INFO Concatenating annotations by spatial chunk
# [2026-02-05 14:58:18,804] INFO Combining annotation and ID buffers for spatial index
# [2026-02-05 14:58:18,805] INFO Writing annotations to 'by_spatial_level_0' index
#   0%|          | 0/1 [00:00<?, ?it/s]
# [2026-02-05 14:58:18,851] INFO Writing annotations to 'by_spatial_level_1' index
#   0%|          | 0/2 [00:00<?, ?it/s]
# [2026-02-05 14:58:18,941] INFO Writing annotations to 'by_spatial_level_2' index
#   0%|          | 0/4 [00:00<?, ?it/s]
# [2026-02-05 14:58:19,121] INFO Writing annotations to 'by_spatial_level_3' index
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
soma_df
# Out:
#                 bodyId                      flywireType     group  \
# segment
# 10001            10001                            DNp01   10001.0
# 10002            10002                           OCG01d   10002.0
# 10003            10003                              VCH   10003.0
# 10005            10005                          AOTU019   10005.0
# 10006            10006  VS1,VS2,VS3,VS4,VS5,VS6,VS7,VS8   10006.0
# ...                ...                              ...       ...
# 1105041427  1105041427                             None  811410.0
# 1121362744  1121362744                             None  817389.0
# 1146133661  1146133661                             None       NaN
# 1169329814  1169329814                             None       NaN
# 1327933709  1327933709                             None       NaN
#
#            hemibrainType      instance          itoleeHl somaSide  \
# segment
# 10001        Giant Fiber   DNp01(GF)_R  putative_primary        R
# 10002              OCG01      OCG01d_L                          L
# 10003                VCH         VCH_R  putative_primary        R
# 10005            AOTU019     AOTU019_R  putative_primary        R
# 10006                 VS          VS_L        no_lineage        L
# ...                  ...           ...               ...      ...
# 1105041427          None    IN19A100_L                          L
# 1121362744          None  IN11B022_a_L                          L
# 1146133661          None          None                          R
# 1169329814          None          None                          R
# 1327933709          None          None                          L
#
#                       statusLabel          superclass supertype  ...  \
# segment                                                          ...
# 10001              Roughly traced   descending_neuron      None  ...
# 10002              Roughly traced   visual_projection      None  ...
# 10003       Prelim Roughly traced  visual_centrifugal      None  ...
# 10005              Roughly traced        cb_intrinsic      None  ...
# 10006       Prelim Roughly traced   visual_projection     10006  ...
# ...                           ...                 ...       ...  ...
# 1105041427               Reviewed       vnc_intrinsic      None  ...
# 1121362744               Reviewed       vnc_intrinsic      None  ...
# 1146133661                 Orphan                None      None  ...
# 1169329814                 Orphan                None      None  ...
# 1327933709                 Orphan                None      None  ...
#
#            serialMotif receptorType            somaLocation tosomaLocation  \
# segment
# 10001             None         None   [37124, 22258, 36274]           None
# 10002             None         None   [50214, 10279, 27497]           None
# 10003             None         None   [46716, 21029, 15714]           None
# 10005             None         None   [41190, 18491, 12885]           None
# 10006             None         None   [69604, 28368, 42459]           None
# ...                ...          ...                     ...            ...
# 1105041427        None         None  [60804, 50944, 123736]           None
# 1121362744        None         None   [60914, 46448, 88562]           None
# 1146133661        None         None  [45120, 40512, 124336]           None
# 1169329814        None         None   [35750, 54770, 80766]           None
# 1327933709        None         None   [64648, 60912, 78704]           None
#
#             status                mylabel  has_soma      x      y       z
# segment
# 10001       Traced       DNp01 (has soma)      True  37124  22258   36274
# 10002       Traced      OCG01d (has soma)      True  50214  10279   27497
# 10003       Traced         VCH (has soma)      True  46716  21029   15714
# 10005       Traced     AOTU019 (has soma)      True  41190  18491   12885
# 10006       Traced          VS (has soma)      True  69604  28368   42459
# ...            ...                    ...       ...    ...    ...     ...
# 1105041427  Traced    IN19A100 (has soma)      True  60804  50944  123736
# 1121362744  Traced  IN11B022_a (has soma)      True  60914  46448   88562
# 1146133661  Orphan                    NaN      True  45120  40512  124336
# 1169329814  Orphan                    NaN      True  35750  54770   80766
# 1327933709  Orphan                    NaN      True  64648  60912   78704
#
# [141780 rows x 40 columns]

# %%
# Or add it programmatically to an existing neuroglancer state.
new_state = copy.deepcopy(state)
new_state['layers'].append({
    'name': 'soma_points',
    'source': f'precomputed://{TUTORIAL_DATA_ADDRESS}/soma_annotations'
})
print(ngsk.encode_ngstate('http://neuroglancer-demo.appspot.com', new_state))
# Out:
# http://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%2C%20%7B%22name%22%3A%20%22soma_points%22%2C%20%22source%22%3A%20%22precomputed%3A//http%3A//10.101.10.33%3A9091/soma_annotations%22%7D%5D%2C%20%22showSlices%22%3A%20false%2C%20%22selectedLayer%22%3A%20%7B%22flex%22%3A%201.57%2C%20%22size%22%3A%20415%2C%20%22visible%22%3A%20true%2C%20%22layer%22%3A%20%22cns-seg%22%7D%2C%20%22layout%22%3A%20%224panel-alt%22%7D

# %% [markdown]
# Let's add an annotation shader that uses the properties.

# %%
SHADER = """\
#uicontrol float radius slider(min=1, max=30, step=1, default=5)

uint hash_function(uint state, uint value) {
    uint k1 = 0xcc9e2d51u;
    uint k2 = 0x1b873593u;

    value = value * k1;
    value = (value << 15) | (value >> 17);
    value = value * k2;
    state = state ^ value;
    state = (state << 13) | (state >> 19);
    state = state * 5u + 0xe6546b64u;

    return state;
}

vec3 hsv_to_rgb(float h, float s, float v) {
    h *= 6.0;
    float hue_index = floor(h);
    float remainder = h - hue_index;
    float val1 = v * (1.0 - s);
    float val2 = v * (1.0 - (s * remainder));
    float val3 = v * (1.0 - (s * (1.0 - remainder)));

    int hue_remainder = int(hue_index) % 6;

    if (hue_remainder == 0) {
        return vec3(v, val3, val1);
    } else if (hue_remainder == 1) {
        return vec3(val2, v, val1);
    } else if (hue_remainder == 2) {
        return vec3(val1, v, val3);
    } else if (hue_remainder == 3) {
        return vec3(val1, val2, v);
    } else if (hue_remainder == 4) {
        return vec3(val3, val1, v);
    } else { // hue_remainder == 5
        return vec3(v, val1, val2);
    }
}

vec3 color_from_segment_id(uint color_seed_, uint segment_id) {
    uint result = hash_function(color_seed_, segment_id);

    // We only support 32-bit segment IDs, so newvalue is always 0,
    // and (id >> 32) would be undefined behavior!
    // uint newvalue = id >> 32;

    uint newvalue = 0u;
    uint result2 = hash_function(result, newvalue);

    float c0 = float(result2 & 0xFFu) / 255.0;
    float c1 = float((result2 >> 8) & 0xFFu) / 255.0;

    float h = c0;
    float s = 0.5 + 0.5 * c1;
    float v = 1.0;

    return hsv_to_rgb(h, s, v);
}

void main() {
    setPointMarkerSize(radius);
    setPointMarkerBorderWidth(1.0);
    setPointMarkerBorderColor(vec3(0.0, 0.0, 0.0));

    setColor(vec3(1.0, 1.0, 1.0));

    if (int(prop_itoleeHl()) > 0) {
      setColor(color_from_segment_id(uint(0), uint(prop_itoleeHl())));
    }
    if (int(prop_trumanHl()) > 0) {
      setColor(color_from_segment_id(uint(0), uint(prop_trumanHl())));
    }
}
"""

# Or add it programmatically to an existing neuroglancer state.
new_state = copy.deepcopy(state)
new_state['layers'].append({
    'type': 'annotation',
    'name': 'soma_points',
    'source': f'precomputed://{TUTORIAL_DATA_ADDRESS}/soma_annotations',
    'shader': SHADER
})
print(ngsk.encode_ngstate('http://neuroglancer-demo.appspot.com', new_state))
# Out:
# http://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22Example%20Scene%201%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%2C%20%7B%22type%22%3A%20%22annotation%22%2C%20%22name%22%3A%20%22soma_points%22%2C%20%22source%22%3A%20%22precomputed%3A//http%3A//10.101.10.33%3A9091/soma_annotations%22%2C%20%22shader%22%3A%20%22%23uicontrol%20float%20radius%20slider%28min%3D1%2C%20max%3D30%2C%20step%3D1%2C%20default%3D5%29%5Cn%5Cnuint%20hash_function%28uint%20state%2C%20uint%20value%29%20%7B%5Cn%20%20%20%20uint%20k1%20%3D%200xcc9e2d51u%3B%5Cn%20%20%20%20uint%20k2%20%3D%200x1b873593u%3B%5Cn%5Cn%20%20%20%20value%20%3D%20value%20%2A%20k1%3B%5Cn%20%20%20%20value%20%3D%20%28value%20%3C%3C%2015%29%20%7C%20%28value%20%3E%3E%2017%29%3B%5Cn%20%20%20%20value%20%3D%20value%20%2A%20k2%3B%5Cn%20%20%20%20state%20%3D%20state%20%5E%20value%3B%5Cn%20%20%20%20state%20%3D%20%28state%20%3C%3C%2013%29%20%7C%20%28state%20%3E%3E%2019%29%3B%5Cn%20%20%20%20state%20%3D%20state%20%2A%205u%20%2B%200xe6546b64u%3B%5Cn%5Cn%20%20%20%20return%20state%3B%5Cn%7D%5Cn%5Cnvec3%20hsv_to_rgb%28float%20h%2C%20float%20s%2C%20float%20v%29%20%7B%5Cn%20%20%20%20h%20%2A%3D%206.0%3B%5Cn%20%20%20%20float%20hue_index%20%3D%20floor%28h%29%3B%5Cn%20%20%20%20float%20remainder%20%3D%20h%20-%20hue_index%3B%5Cn%20%20%20%20float%20val1%20%3D%20v%20%2A%20%281.0%20-%20s%29%3B%5Cn%20%20%20%20float%20val2%20%3D%20v%20%2A%20%281.0%20-%20%28s%20%2A%20remainder%29%29%3B%5Cn%20%20%20%20float%20val3%20%3D%20v%20%2A%20%281.0%20-%20%28s%20%2A%20%281.0%20-%20remainder%29%29%29%3B%5Cn%5Cn%20%20%20%20int%20hue_remainder%20%3D%20int%28hue_index%29%20%25%206%3B%5Cn%5Cn%20%20%20%20if%20%28hue_remainder%20%3D%3D%200%29%20%7B%5Cn%20%20%20%20%20%20%20%20return%20vec3%28v%2C%20val3%2C%20val1%29%3B%5Cn%20%20%20%20%7D%20else%20if%20%28hue_remainder%20%3D%3D%201%29%20%7B%5Cn%20%20%20%20%20%20%20%20return%20vec3%28val2%2C%20v%2C%20val1%29%3B%5Cn%20%20%20%20%7D%20else%20if%20%28hue_remainder%20%3D%3D%202%29%20%7B%5Cn%20%20%20%20%20%20%20%20return%20vec3%28val1%2C%20v%2C%20val3%29%3B%5Cn%20%20%20%20%7D%20else%20if%20%28hue_remainder%20%3D%3D%203%29%20%7B%5Cn%20%20%20%20%20%20%20%20return%20vec3%28val1%2C%20val2%2C%20v%29%3B%5Cn%20%20%20%20%7D%20else%20if%20%28hue_remainder%20%3D%3D%204%29%20%7B%5Cn%20%20%20%20%20%20%20%20return%20vec3%28val3%2C%20val1%2C%20v%29%3B%5Cn%20%20%20%20%7D%20else%20%7B%20//%20hue_remainder%20%3D%3D%205%5Cn%20%20%20%20%20%20%20%20return%20vec3%28v%2C%20val1%2C%20val2%29%3B%5Cn%20%20%20%20%7D%5Cn%7D%5Cn%5Cnvec3%20color_from_segment_id%28uint%20color_seed_%2C%20uint%20segment_id%29%20%7B%5Cn%20%20%20%20uint%20result%20%3D%20hash_function%28color_seed_%2C%20segment_id%29%3B%5Cn%5Cn%20%20%20%20//%20We%20only%20support%2032-bit%20segment%20IDs%2C%20so%20newvalue%20is%20always%200%2C%5Cn%20%20%20%20//%20and%20%28id%20%3E%3E%2032%29%20would%20be ...
