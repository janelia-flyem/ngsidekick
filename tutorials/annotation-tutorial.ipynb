# %%
import json
import numpy as np
import pandas as pd

import ngsidekick as ngsk

# %% [markdown]
# # Neuroglancer State

# %% [markdown]
# Neuroglancer links encode a JSON object that captures nearly all viewer state: layer visibility, camera orientation, etc.
#
# Let's start with the default [MaleCNS scene][1].
#
# [1]: https://neuroglancer-demo.appspot.com/#!gs://flyem-male-cns/v0.9/male-cns-v0.9.json

# %%
state = ngsk.parse_nglink('https://neuroglancer-demo.appspot.com/#!gs://flyem-male-cns/v0.9/male-cns-v0.9.json')

# %% [markdown]
# Most of the top-level keys control the global viewer settings: Coordinate space, camera orientation, zoom level, panel layout, etc.

# %%
list(state.keys())
# Out:
# ['title',
#  'dimensions',
#  'position',
#  'crossSectionScale',
#  'projectionOrientation',
#  'projectionScale',
#  'layers',
#  'showSlices',
#  'gpuMemoryLimit',
#  'systemMemoryLimit',
#  'selectedLayer',
#  'layout',
#  'selection',
#  'layerListPanel']

# %% [markdown]
# Neuroglancer stores the layers as a list (to preserve their order), but for programmatic manipulation it's convenient to access them by their `name`.  Here's a convenience function for that:

# %%
seg_layer = ngsk.layer_state(state, 'cns-seg')

# %%
# Select two neurons.
seg_layer['segments'] = ["10009", "10157"]

# %% [markdown]
# A (non-shortened) neuroglancer link includes the complete JSON state directly in the URL.  (It might be pretty long!)
#
# To turn our state into a URL, just URL-encode the JSON text and give it an appropriate prefix.

# %%
import urllib

encoded_state = urllib.parse.quote(json.dumps(state))

print("https://neuroglancer-demo.appspot.com/#!" + encoded_state)
# Out:
# https://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22MaleCNS%20v0.9%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%5B%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/type_property%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/type_and_group_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/tags_property%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/numeric_properties%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/instance_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/flywireType_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/meshes-malecns/single-res-meshes%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%5D%2C%20%22toolBindings%22%3A%20%7B%22Q%22%3A%20%22selectSegments%22%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%2210009%22%2C%20%2210157%22%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/rois/fullbrain-major-shells%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22pick%22%3A%20false%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22selectedAlpha%22%3A%200%2C%20%22saturation%22%3A%200%2C%20%22meshSilhouetteRendering%22%3A%207%2C%20%22segments%22%3A%20%5B%221%22%2C%20%222%22%2C%20%223%22%5D%2C%20%22segmentDefaultColor%22%3A%20%22%23ffffff%22%2C%20%22name%22%3A%20%22brain-neuropil-shell%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/rois/brain-shell-v2.2%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22pick%22%3A%20false%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22selectedAlpha%22%3A%200%2C%20%22saturation%22%3A%200%2C%20%22meshSilhouetteRendering%22%3A%207%2C%20%22segments%22%3A%20%5B%221%22%5D%2C%20%22segmentDefaultColor%22%3A%20%22%23ffffff%22%2C%20%22name%22%3A%20%22brain-shell%22%2C%20%22archived%22%3A%20true%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//fl ...

# %% [markdown]
# It can be cumbersome to share long links, and not all standard link shorteners can handle neuroglancer links with complete fidelity. Fortunately, neuroglancer can also unpack the JSON state from a JSON file (as shown above in the link we used to load the initial state).  However, that requires hosting the JSON file somewhere, either over `https` or in a Google Storage bucket (prefixed with `gs://`).
#
# Janelia FlyEM offers a [neuroglancer link shortener][shortng] that stores your link in a GCS bucket (with caveats).  In addition to the Web UI, it has a REST API as shown here.
#
# [shortng]: https://shortng-bmcp5imp6q-uc.a.run.app/shortener.html
#
# (If you prefer to use your own GCS bucket, see the convenience functions in [`ngsidekick.gcs`][gcs].)
#
# [gcs]: https://janelia-flyem.github.io/ngsidekick/docs/gcs.html

# %%
import requests

SHORTENER_URL = 'https://shortng-bmcp5imp6q-uc.a.run.app'

r = requests.post(f'{SHORTENER_URL}/shortng', json={
        'state': state,

        # Optional: A default name is chosen if you don't provide one.
        'filename': 'my-state.json',

        # Optional: A password to prevent others from writing to the same filename.
        # Note: Does NOT prevent others from using your link!
        'password': 'my-password',
    })

print(r.json())
# Out:
# {'link': 'https://neuroglancer-demo.appspot.com/#!gs://flyem-user-links/short/my-state.json'}

# %% [markdown]
# # Download Example data
#
# MaleCNS neuron properties and soma locations.
#
# Obtained from the [MaleCNS download page.][1]
#
# [1]: https://male-cns.janelia.org/download

# %%
body_annotations_url = 'https://storage.googleapis.com/flyem-male-cns/v0.9/connectome-data/flat-connectome/body-annotations-male-cns-v0.9-minconf-0.5.feather'
df = pd.read_feather(body_annotations_url)

# The "type" column has the cell type, but later on we'll use "type" to mean something else,
# so rename "type" -> "cell_type"
df = df.rename(columns={'type': 'cell_type'})

print(df.columns)
df.head()
# Out:
# Index(['bodyId', 'flywireType', 'group', 'hemibrainType', 'instance',
#        'itoleeHl', 'somaSide', 'statusLabel', 'superclass', 'supertype',
#        'cell_type', 'class', 'entryNerve', 'fruDsx', 'matchingNotes',
#        'rootSide', 'assignedOlHex1', 'assignedOlHex2', 'mancBodyid',
#        'mancGroup', 'mancType', 'somaNeuromere', 'subclass', 'trumanHl',
#        'dimorphism', 'synonyms', 'birthtime', 'mancSerial', 'mcnsSerial',
#        'exitNerve', 'serialMotif', 'receptorType', 'somaLocation',
#        'tosomaLocation', 'status'],
#       dtype='object')
#    bodyId                      flywireType    group hemibrainType  \
# 0   10001                            DNp01  10001.0   Giant Fiber
# 1   10002                           OCG01d  10002.0         OCG01
# 2   10003                              VCH  10003.0           VCH
# 3   10005                          AOTU019  10005.0       AOTU019
# 4   10006  VS1,VS2,VS3,VS4,VS5,VS6,VS7,VS8  10006.0            VS
#
#       instance          itoleeHl somaSide            statusLabel  \
# 0  DNp01(GF)_R  putative_primary        R         Roughly traced
# 1     OCG01d_L              None        L         Roughly traced
# 2        VCH_R  putative_primary        R  Prelim Roughly traced
# 3    AOTU019_R  putative_primary        R         Roughly traced
# 4         VS_L        no_lineage        L  Prelim Roughly traced
#
#            superclass supertype  ...                      synonyms birthtime  \
# 0   descending_neuron      None  ...  Kennedy and Broadie 2018: GF     early
# 1   visual_projection      None  ...                          None      None
# 2  visual_centrifugal      None  ...                          None     early
# 3        cb_intrinsic      None  ...                          None     early
# 4   visual_projection     10006  ...                          None      None
#
#   mancSerial mcnsSerial exitNerve serialMotif  receptorType  \
# 0        NaN        NaN      None        None          None
# 1        NaN        NaN      None        None          None
# 2        NaN        NaN      None        None          None
# 3        NaN        NaN      None        None          None
# 4        NaN        NaN      None        None          None
#
#             somaLocation  tosomaLocation  status
# 0  [37124, 22258, 36274]            None  Traced
# 1  [50214, 10279, 27497]            None  Traced
# 2  [46716, 21029, 15714]            None  Traced
# 3  [41190, 18491, 12885]            None  Traced
# 4  [69604, 28368, 42459]            None  Traced
#
# [5 rows x 35 columns]

# %%
# Extract the rows with a soma location
soma_df = df.dropna(subset='somaLocation').copy()
soma_df[[*'xyz']] = soma_df['somaLocation'].tolist()

print(soma_df.shape)
soma_df[['bodyId', *'xyz']].head()
# Out:
# (141780, 38)
#    bodyId      x      y      z
# 0   10001  37124  22258  36274
# 1   10002  50214  10279  27497
# 2   10003  46716  21029  15714
# 3   10005  41190  18491  12885
# 4   10006  69604  28368  42459

# %% [markdown]
# # Local Annotations
# To visualize just a few points, neuroglancer allows "local" annotations -- stored directly in the neuroglancer link (JSON state).

# %%
# Neuroglancer allows local annotation layers to contain a mix of annotation types (points, lines, boxes, etc.)
Tm9_soma_df = soma_df.query('cell_type == "Tm9"')
Tm9_soma_layer_json = ngsk.local_annotation_json(Tm9_soma_df)

# The output below can be pasted into the neuroglancer state.
print(json.dumps(Tm9_soma_layer_json))
# Out:
# {"name": "annotations", "type": "annotation", "source": {"url": "local://annotations", "transform": {"outputDimensions": {"x": [8e-09, "m"], "y": [8e-09, "m"], "z": [8e-09, "m"]}}}, "tool": "annotatePoint", "shader": "void main() {\n    //\n    // Point Marker API\n    //\n    setPointMarkerSize(8.0);\n    setPointMarkerColor(vec4(defaultColor(), 1.0));\n    setPointMarkerBorderWidth(1.0);\n    setPointMarkerBorderColor(defaultColor());\n}\n", "annotations": [{"type": "point", "id": "0x2a7934f02e0d6823", "point": [75339, 18690, 24056]}, {"type": "point", "id": "0x4b9370cd71e8816a", "point": [82763, 46908, 29906]}, {"type": "point", "id": "0x34c65fe2673b9559", "point": [81099, 40221, 23977]}, {"type": "point", "id": "0x224800863a7c437e", "point": [76408, 21362, 22562]}, {"type": "point", "id": "0x522b547201d30fc2", "point": [89208, 18548, 33472]}, {"type": "point", "id": "0x4bc2d7736c5b7e5", "point": [78398, 33256, 20886]}, {"type": "point", "id": "0x3fa669bf774e5d7b", "point": [91380, 37474, 31212]}, {"type": "point", "id": "0x60331b98530ea266", "point": [86988, 43496, 28908]}, {"type": "point", "id": "0x1cfcbe38b8be4e7b", "point": [80244, 34418, 21788]}, {"type": "point", "id": "0x7b3ffc408b93ed5c", "point": [78968, 42843, 24010]}, {"type": "point", "id": "0x45b5f88637a77677", "point": [78974, 15360, 26168]}, {"type": "point", "id": "0x7b6ab2eab1afb4ed", "point": [90914, 30968, 36716]}, {"type": "point", "id": "0x76a160979ff3b853", "point": [90916, 35030, 32320]}, {"type": "point", "id": "0x4075d7fc741ae328", "point": [7974, 41520, 39594]}, {"type": "point", "id": "0x792461985e05ac6a", "point": [90386, 24430, 32466]}, {"type": "point", "id": "0x6a699c14fe1a3ee9", "point": [91208, 35470, 34788]}, {"type": "point", "id": "0x3fe9cc04165dc5ba", "point": [78954, 47734, 26750]}, {"type": "point", "id": "0x7b893cbffc9d1cdd", "point": [85152, 23446, 29218]}, {"type": "point", "id": "0x365f01312be03573", "point": [87090, 44942, 35856]}, {"type": "point", "id": "0x110b5acc06a47e98", "point": [83174, 14468, 33772]}, {"type": "point", "id": "0x7188fdf564d4c025", "point": [77070, 43774, 23050]}, {"type": "point", "id": "0x3a58e1decea160d7", "point": [91330, 32194, 35138]}, {"type": "point", "id": "0x4bb8e92339d7fdb9", "point": [85594, 45072, 29256]}, {"type": "point", "id": "0x59878bd0e7b8be6d", "point": [79046, 45136, 25236]}, {"type": "point", "id": "0x610b7cc0122afd81", "point": [82027, 47174, 37329]}, {"type": "point", "id": "0xa8c2977fd7f9221", "point": [86302, 43390, 28776]}, {"type": "point", "id": "0x133021a1a0b18fff", "point": [88126, 41877, 34916]}, {"type": "point", "id": "0x2982d812de584755", "point": [80954, 43384, 26570]}, {"type": "point", "id": "0x11508b04cff7cb9b", "point": [78364, 49828, 31622]}, {"type": "point", "id": "0x5841e49c14b9b06f", "point": [73570, 43211, 24113]}, {"type": "point", "id": "0x58578c1e4062b863", "point": [89757, 40022, 30422]}, {"type": "point", "id": "0x730a482eeff830a", "point": [92661, 26193, 34118]}, {"type": "point", "id": "0x2510716721eccbe6", "point": [72232, 40344, 23604]}, {"type": "point", "id": "0x2de4f7caa35cdb9b", "point": [89818, 33816, 38486]}, {"type": "point", "id": "0x3cef4b28eac9a2a7", "point": [87746, 43871, 32218]}, {"type": "point", "id": "0x7515b11f282cd526", "point": [91288, 29947, 35593]}, {"type": "point", "id": "0x33838fc96a4f5318", "point": [72839, 30167, 21461]}, {"type": "point", "id": "0x2c0ce0774bcfc890", "point": [79266, 38436, 22762]}, {"type": "point", "id": "0x10247b6976375fd5", "point": [80642, 43502, 24748]}, {"type": "point", "id": "0x308ac8cf9946c4bf", "point": [12248, 34049, 27554]}, {"type": "point", "id": "0x6401d442adefbdc9", "point": [75076, 36658, 21490]}, {"type": "point", "id": "0x8ddb86eab1cefb0", "point": [75194, 12738, 26808]}, {"type": "point", "id": "0x2dc987cd4c32b9c0", "point": [15762, 16766, 28600]}, {"type": "point", "id": "0x25465bf84c7ea69a", "point": [82382, 28766, 24450]}, {"type": "point", "id": "0x77b716ca1a36d0cc", "point": [76836, 48 ...

# %%
# Or add it programmatically to an existing neuroglancer state.
state = ngsk.parse_nglink('https://neuroglancer-demo.appspot.com/#!gs://flyem-male-cns/v0.9/male-cns-v0.9.json')
state['layers'].append(Tm9_soma_layer_json)
print(ngsk.encode_ngstate('https://neuroglancer-demo.appspot.com', state))
# Out:
# https://neuroglancer-demo.appspot.com/#!%7B%22title%22%3A%20%22MaleCNS%20v0.9%22%2C%20%22dimensions%22%3A%20%7B%22x%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22y%22%3A%20%5B8e-09%2C%20%22m%22%5D%2C%20%22z%22%3A%20%5B8e-09%2C%20%22m%22%5D%7D%2C%20%22position%22%3A%20%5B48311.5%2C%2025295.765625%2C%2028511.5%5D%2C%20%22crossSectionScale%22%3A%2088.13122564876332%2C%20%22projectionOrientation%22%3A%20%5B0%2C%20-0.002181659685447812%2C%200%2C%200.999997615814209%5D%2C%20%22projectionScale%22%3A%2099656.51830908704%2C%20%22layers%22%3A%20%5B%7B%22type%22%3A%20%22image%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/em/em-clahe-jpeg%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22name%22%3A%20%22em-clahe%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%5B%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/type_property%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/type_and_group_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/tags_property%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/numeric_properties%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/instance_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/flywireType_property%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/v0.9/segmentation/meshes-malecns/single-res-meshes%22%2C%20%22enableDefaultSubsources%22%3A%20false%7D%5D%2C%20%22toolBindings%22%3A%20%7B%22Q%22%3A%20%22selectSegments%22%7D%2C%20%22tab%22%3A%20%22segments%22%2C%20%22segments%22%3A%20%5B%5D%2C%20%22name%22%3A%20%22cns-seg%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/rois/fullbrain-major-shells%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22pick%22%3A%20false%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22selectedAlpha%22%3A%200%2C%20%22saturation%22%3A%200%2C%20%22meshSilhouetteRendering%22%3A%207%2C%20%22segments%22%3A%20%5B%221%22%2C%20%222%22%2C%20%223%22%5D%2C%20%22segmentDefaultColor%22%3A%20%22%23ffffff%22%2C%20%22name%22%3A%20%22brain-neuropil-shell%22%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/rois/brain-shell-v2.2%22%2C%20%22subsources%22%3A%20%7B%22default%22%3A%20true%2C%20%22properties%22%3A%20true%2C%20%22mesh%22%3A%20true%7D%2C%20%22enableDefaultSubsources%22%3A%20false%7D%2C%20%22pick%22%3A%20false%2C%20%22tab%22%3A%20%22rendering%22%2C%20%22selectedAlpha%22%3A%200%2C%20%22saturation%22%3A%200%2C%20%22meshSilhouetteRendering%22%3A%207%2C%20%22segments%22%3A%20%5B%221%22%5D%2C%20%22segmentDefaultColor%22%3A%20%22%23ffffff%22%2C%20%22name%22%3A%20%22brain-shell%22%2C%20%22archived%22%3A%20true%7D%2C%20%7B%22type%22%3A%20%22segmentation%22%2C%20%22source%22%3A%20%7B%22url%22%3A%20%22precomputed%3A//gs%3A//flyem-male-cns/rois/brain-shel ...

# %%
long_link = ngsk.encode_ngstate('https://neuroglancer-demo.appspot.com', state)

import requests
SHORTENER_URL = 'https://shortng-bmcp5imp6q-uc.a.run.app'
r = requests.post(f'{SHORTENER_URL}/shortng', json={'text': Tm9_soma_layer_json})
r.content
# Out:
# b'<!doctype html>\n<html lang=en>\n<title>500 Internal Server Error</title>\n<h1>Internal Server Error</h1>\n<p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>\n'
